# %% [markdown]
# # 01 — Data Exploration
#
# This notebook gives an initial overview of the student performance dataset before modelling.
#
# **Goal:** understand the dataset structure, its size, and the main variables.

# %%
import pandas as pd

df = pd.read_csv("../data/student-mat.csv", sep=";")
df.head()

# %% [markdown]
# ## Dataset size

# %%
df.shape

# %% [markdown]
# The dataset contains **395 students** and **33 columns**. The target variable for this project is **G3**, the final grade.

# %% [markdown]
# ## Columns

# %%
df.columns

# %% [markdown]
# ## Data types and basic information

# %%
df.info()

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()

# %% [markdown]
# ## Target variable: G3

# %%
print("Mean G3:", df["G3"].mean())
print("Median G3:", df["G3"].median())

# %% [markdown]
# ### Takeaway
#
# The dataset contains demographic, family, school, social and academic information. The next step is to check data quality before exploring relationships between the variables.
